# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
tf_pivoted=pd.read_csv("C:/Users/HP/Desktop/TestBDA/data/WDI_FINAL_TRANSFORMED.csv", header=0, index_col=None)

# %%
filtered_df = tf_pivoted[(tf_pivoted['Country_Name'] == 'China' )& (tf_pivoted['Indicator_Code'] == 'SP.POP.TOTL')]

# %%
filtered_df
# Out:
#          Country_Name Country_Code     Indicator_Name Indicator_Code  Year  \
# 134100          China          CHN  Population, total    SP.POP.TOTL  1983
# 527248          China          CHN  Population, total    SP.POP.TOTL  1984
# 920396          China          CHN  Population, total    SP.POP.TOTL  1985
# 1313544         China          CHN  Population, total    SP.POP.TOTL  1986
# 1706692         China          CHN  Population, total    SP.POP.TOTL  1987
# 2099840         China          CHN  Population, total    SP.POP.TOTL  1988
# 2492988         China          CHN  Population, total    SP.POP.TOTL  1989
# 2886136         China          CHN  Population, total    SP.POP.TOTL  1990
# 3279284         China          CHN  Population, total    SP.POP.TOTL  1991
# 3672432         China          CHN  Population, total    SP.POP.TOTL  1992
# 4065580         China          CHN  Population, total    SP.POP.TOTL  1993
# ...

# %%
column_sum = filtered_df['Value'].sum()

# %%
column_sum/1000000
# Out:
# 49008.41

# %%
tf_pivoted=pd.read_csv("C:/Users/HP/Desktop/TestBDA/data/WDI_FINAL_TRANSFORMED.csv", header=0, index_col=None)

# %%
tf_pivoted.dtypes
# Out:
# Country_Name       object
# Country_Code       object
# Indicator_Name     object
# Indicator_Code     object
# Year                int64
# Value             float64
# dtype: object

# %%
tf_pivoted['Indicator_Name']
# Out:
# 0           Access to clean fuels and technologies for coo...
# 1           Access to clean fuels and technologies for coo...
# 2           Access to clean fuels and technologies for coo...
# 3                     Access to electricity (% of population)
# 4           Access to electricity, rural (% of rural popul...
#                                   ...
# 15332767    Women who believe a husband is justified in be...
# 15332768    Women who were first married by age 15 (% of w...
# 15332769    Women who were first married by age 18 (% of w...
# 15332770    Women's share of population ages 15+ living wi...
# 15332771    Young people (ages 15-24) newly infected with HIV
# Name: Indicator_Name, Length: 15332772, dtype: object

# %%
tf_pivoted['Indicator_Name'] = tf_pivoted['Indicator_Name'].str.replace(',', '')

# %%
tf_pivoted['Indicator_Name'].nunique()
# Out:
# 1478

# %%
tf_pivoted['Indicator_Name'].unique()
# Out:
# array(['Access to clean fuels and technologies for cooking (% of population)',
#        'Access to clean fuels and technologies for cooking rural (% of rural population)',
#        'Access to clean fuels and technologies for cooking urban (% of urban population)',
#        ...,
#        'Women who were first married by age 18 (% of women ages 20-24)',
#        "Women's share of population ages 15+ living with HIV (%)",
#        'Young people (ages 15-24) newly infected with HIV'], dtype=object)

# %%
tf_pivoted.to_csv('C:/Users/HP/Desktop/TestBDA/data/WDI_FINAL_TRANSFORMED2.csv', index=False)

# %%
tf_pivoted
# Out:
#                          Country_Name Country_Code  \
# 0         Africa Eastern and Southern          AFE
# 1         Africa Eastern and Southern          AFE
# 2         Africa Eastern and Southern          AFE
# 3         Africa Eastern and Southern          AFE
# 4         Africa Eastern and Southern          AFE
# ...                               ...          ...
# 15332767                     Zimbabwe          ZWE
# 15332768                     Zimbabwe          ZWE
# 15332769                     Zimbabwe          ZWE
# 15332770                     Zimbabwe          ZWE
# 15332771                     Zimbabwe          ZWE
#
#                                              Indicator_Name  \
# 0         Access to clean fuels and technologies for coo...
# 1         Access to clean fuels and technologies for coo...
# 2         Access to clean fuels and technologies for coo...
# 3                   Access to electricity (% of population)
# ...

# %%
#Load the indicators csv
#Put the csv into a list
#Load all values from the main file based on the indicators
#Select countries and then load
#Make a final csv

# %%
final=pd.read_csv("C:/Users/HP/Desktop/TestBDA/data/FINAL/WDI_FINAL_TRANSFORMED2.csv", header=0, index_col=None)

# %%
indicators=pd.read_csv("C:/Users/HP/Desktop/TestBDA/data/FINAL/indicators.csv", header=0, index_col=None)

# %%
indicators['Indicator_Code'].nunique()
# Out:
# 34

# %%
final_indicators = indicators['Indicator_Code'].unique().tolist()

# %%
final_indicators
# Out:
# ['SP.POP.TOTL',
#  'SP.POP.TOTL.FE.IN',
#  'SP.POP.TOTL.MA.IN',
#  'SP.DYN.CBRT.IN',
#  'SP.DYN.CDRT.IN',
#  'SP.DYN.LE00.IN',
#  'SP.POP.GROW',
#  'IQ.CPA.GNDR.XQ',
#  'SH.XPD.CHEX.GD.ZS',
#  'SL.EMP.1524.SP.NE.ZS',
#  'SE.ADT.LITR.ZS',
#  'EG.ELC.ACCS.ZS',
#  'SL.UEM.TOTL.NE.ZS',
#  'SL.UEM.1524.NE.ZS',
#  'NY.ADJ.NNTY.KD.ZG',
#  'FM.LBL.BMNY.GD.ZS',
#  'GC.DOD.TOTL.GD.ZS',
#  'GC.DOD.TOTL.CN',
#  'BN.CAB.XOKA.GD.ZS',
#  'GC.XPN.TOTL.GD.ZS',
#  'GC.XPN.TOTL.CN',
#  'EG.USE.COMM.FO.ZS',
#  'NY.GDP.MKTP.KD.ZG',
#  'GC.TAX.TOTL.GD.ZS',
#  'NY.GNS.ICTR.ZS',
#  'FP.CPI.TOTL.ZG',
#  'NY.GSR.NFCY.CD',
#  'NY.ADJ.AEDU.CD',
#  'SE.SEC.UNER.LO.ZS',
#  'SL.TLF.0714.ZS',
#  'SE.PRM.UNER.ZS',
#  'SE.COM.DURS',
#  'SE.TER.CUAT.BA.ZS',
#  'SE.XPD.TOTL.GD.ZS']

# %%
final
# Out:
#                          Country_Name Country_Code  \
# 0         Africa Eastern and Southern          AFE
# 1         Africa Eastern and Southern          AFE
# 2         Africa Eastern and Southern          AFE
# 3         Africa Eastern and Southern          AFE
# 4         Africa Eastern and Southern          AFE
# ...                               ...          ...
# 15332767                     Zimbabwe          ZWE
# 15332768                     Zimbabwe          ZWE
# 15332769                     Zimbabwe          ZWE
# 15332770                     Zimbabwe          ZWE
# 15332771                     Zimbabwe          ZWE
#
#                                              Indicator_Name  \
# 0         Access to clean fuels and technologies for coo...
# 1         Access to clean fuels and technologies for coo...
# 2         Access to clean fuels and technologies for coo...
# 3                   Access to electricity (% of population)
# ...

# %%
new_df = final[final['Indicator_Code'].isin(final_indicators)]

# %%
new_df
# Out:
#                          Country_Name Country_Code  \
# 3         Africa Eastern and Southern          AFE
# 22        Africa Eastern and Southern          AFE
# 37        Africa Eastern and Southern          AFE
# 51        Africa Eastern and Southern          AFE
# 122       Africa Eastern and Southern          AFE
# ...                               ...          ...
# 15332372                     Zimbabwe          ZWE
# 15332374                     Zimbabwe          ZWE
# 15332628                     Zimbabwe          ZWE
# 15332725                     Zimbabwe          ZWE
# 15332731                     Zimbabwe          ZWE
#
#                                              Indicator_Name  \
# 3                   Access to electricity (% of population)
# 22           Adjusted net national income (annual % growth)
# 37        Adjusted savings: education expenditure (curre...
# 51        Adolescents out of school (% of lower secondar...
# ...

# %%
new_df['Indicator_Code'].value_counts()
# Out:
# EG.ELC.ACCS.ZS          10374
# SE.ADT.LITR.ZS          10374
# EG.USE.COMM.FO.ZS       10374
# NY.GDP.MKTP.KD.ZG       10374
# SE.XPD.TOTL.GD.ZS       10374
# NY.GNS.ICTR.ZS          10374
# FP.CPI.TOTL.ZG          10374
# SP.DYN.LE00.IN          10374
# NY.GSR.NFCY.CD          10374
# NY.ADJ.NNTY.KD.ZG       10374
# SP.POP.GROW             10374
# SP.POP.TOTL.FE.IN       10374
# SP.POP.TOTL.MA.IN       10374
# SP.POP.TOTL             10374
# GC.TAX.TOTL.GD.ZS       10374
# SL.UEM.TOTL.NE.ZS       10374
# GC.XPN.TOTL.CN          10374
# GC.XPN.TOTL.GD.ZS       10374
# SL.EMP.1524.SP.NE.ZS    10374
# SE.TER.CUAT.BA.ZS       10374
# SP.DYN.CDRT.IN          10374
# SH.XPD.CHEX.GD.ZS       10374
# BN.CAB.XOKA.GD.ZS       10374
# IQ.CPA.GNDR.XQ          10374
# SE.COM.DURS             10374
# SE.PRM.UNER.ZS          10374
# SL.TLF.0714.ZS          10374
# GC.DOD.TOTL.CN          10374
# GC.DOD.TOTL.GD.ZS       10374
# FM.LBL.BMNY.GD.ZS       10374
# SP.DYN.CBRT.IN          10374
# ...

# %%
new_df = new_df.drop('Indicator_Name', axis=1)

# %%
new_df
# Out:
#                          Country_Name Country_Code     Indicator_Code  Year  \
# 3         Africa Eastern and Southern          AFE     EG.ELC.ACCS.ZS  1983
# 22        Africa Eastern and Southern          AFE  NY.ADJ.NNTY.KD.ZG  1983
# 37        Africa Eastern and Southern          AFE     NY.ADJ.AEDU.CD  1983
# 51        Africa Eastern and Southern          AFE  SE.SEC.UNER.LO.ZS  1983
# 122       Africa Eastern and Southern          AFE     SP.DYN.CBRT.IN  1983
# ...                               ...          ...                ...   ...
# 15332372                     Zimbabwe          ZWE  SP.POP.TOTL.MA.IN  2021
# 15332374                     Zimbabwe          ZWE        SP.POP.TOTL  2021
# 15332628                     Zimbabwe          ZWE  GC.TAX.TOTL.GD.ZS  2021
# 15332725                     Zimbabwe          ZWE  SL.UEM.TOTL.NE.ZS  2021
# 15332731                     Zimbabwe          ZWE  SL.UEM.1524.NE.ZS  2021
#
#                  Value
# 3         1.099323e+12
# ...

# %%
new_df.to_csv('C:/Users/HP/Desktop/TestBDA/data/FINAL/FINAL.csv', index=False)

# %% [markdown]
# USA-CHN-IND-PAK-BGD-KOR-JPN-ARE-RUS-
